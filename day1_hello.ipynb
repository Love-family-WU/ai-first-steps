# %%
import
``` torch

# 1. 创建一个张量
x = torch.rand(5, 3)
```print("我的第一个张量:\n", x)

# 2. 看看有没有显卡 (
```本地通常是 False，但这代表环境装好了)
print("\n显卡状态:", torch.cuda.is_available
```())
# Out:
#   Cell In[1], line 9
#     ```本地通常是 False，但这代表环境装好了)
#                   ^
# SyntaxError: invalid character '，' (U+FF0C)

# %%
import torch

# 1. 创建一个张量 (这是 AI 的原子)
x = torch.rand(5, 3)
print("我的第一个张量:\n", x)

# 2. 检查显卡是否就位
print("\n我有显卡在帮我跑吗?:", torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       3 # 1. 创建一个张量 (这是 AI 的原子)
#       4 x = torch.rand(5, 3)
#
# ModuleNotFoundError: No module named 'torch'

# %%
import torch

# 1. 创建一个张量 (这是 AI 的原子)
x = torch.rand(5, 3)
print("我的第一个张量:\n", x)

# 2. 检查显卡是否就位
print("\n我有显卡在帮我跑吗?:", torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       3 # 1. 创建一个张量 (这是 AI 的原子)
#       4 x = torch.rand(5, 3)
#
# ModuleNotFoundError: No module named 'torch'

# %%
import torch

# 1. 创建一个张量 (这是 AI 的原子)
x = torch.rand(5, 3)
print("我的第一个张量:\n", x)

# 2. 检查显卡是否就位
print("\n我有显卡在帮我跑吗?:", torch.cuda.is_available())
# Out:
# 我的第一个张量:
#  tensor([[0.7045, 0.1132, 0.0448],
#         [0.4767, 0.9987, 0.1168],
#         [0.8253, 0.1572, 0.3127],
#         [0.3076, 0.3846, 0.0270],
#         [0.3598, 0.9667, 0.4049]])
#
# 我有显卡在帮我跑吗?: False
